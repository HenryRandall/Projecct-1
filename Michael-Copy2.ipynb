# %%
# Dependencies and Setup
from census import Census
from us import states
from config import (census_key, gkey)
import us
import gmaps
import os
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from sodapy import Socrata
import requests
import json

# %%
file='counties.csv'
data_df=pd.read_csv(file,encoding='ISO-8859-1')
data_df
# Out:
#        FIPS       County      State   Latitude   Longitude  confirm_5  \
# 0      1001      Autauga    Alabama  32.539527  -86.644082        6.0
# 1      1003      Baldwin    Alabama  30.727750  -87.722071        1.0
# 2      1005      Barbour    Alabama  31.868263  -85.387129        3.0
# 3      1007         Bibb    Alabama  32.996421  -87.125115        4.0
# 4      1009       Blount    Alabama  33.982109  -86.567906        5.0
# 5      1011      Bullock    Alabama  32.100305  -85.712655        3.0
# 6      1013       Butler    Alabama  31.753001  -86.680575        1.0
# 7      1015      Calhoun    Alabama  33.774837  -85.826304        1.0
# 8      1017     Chambers    Alabama  32.913601  -85.390727        2.0
# 9      1019     Cherokee    Alabama  34.178060  -85.606390        2.0
# 10     1021      Chilton    Alabama  32.850441  -86.717326        7.0
# 11     1023      Choctaw    Alabama  32.022273  -88.265644        2.0
# 12     1025       Clarke    Alabama  31.680999  -87.835486        9.0
# 13     1027         Clay    Alabama  33.269842  -85.858361        2.0
# 14     1029     Cleburne    Alabama  33.676792  -85.520059        5.0
# 15     1031       Coffee    Alabama  31.399328  -85.989010        0.0
# 16     1033      Colbert    Alabama  34.698475  -87.801685        2.0
# 17     1035      Conecuh    Alabama  31.434017  -86.993200        2.0
# 18     1037        Coosa    Alabama  32.936901  -86.248477        3.0
# 19     1039    Covington    Alabama  31.247785  -86.450509        2.0
# 20     1041     Crenshaw    Alabama  31.729418  -86.315931        1.0
# 21     1043      Cullman    Alabama  34.130203  -86.868880        4.0
# 22     1045         Dale    Alabama  31.430371  -85.610957        4.0
# 23     1047       Dallas    Alabama  32.326881  -87.108667        2.0
# 24     1049       DeKalb    Alabama  34.459469  -85.807829        4.0
# 25     1051       Elmore    Alabama  32.597854  -86.144153        4.0
# 26     1053     Escambia    Alabama  31.125679  -87.159187        1.0
# 27     1055       Etowah    Alabama  34.045673  -86.040519        6.0
# 28     1057      Fayette    Alabama  33.720769  -87.738866        1.0
# 29     1059     Franklin    Alabama  34.442353  -87.842895        3.0
# ...     ...          ...        ...        ...         ...        ...
# 3112  55129     Washburn  Wisconsin  45.898386  -91.790504        NaN
# 3113  55131   Washington  Wisconsin  43.368637  -88.229747       14.0
# 3114  55133     Waukesha  Wisconsin  43.018331  -88.304312        3.0
# 3115  55135      Waupaca  Wisconsin  44.470681  -88.965345        1.0
# 3116  55137     Waushara  Wisconsin  44.113244  -89.243171        NaN
# 3117  55139    Winnebago  Wisconsin  44.068869  -88.644771        5.0
# 3118  55141         Wood  Wisconsin  44.455379  -90.041583        1.0
# 3119  56001       Albany    Wyoming  41.654987 -105.723542        1.0
# 3120  56003     Big Horn    Wyoming  44.524051 -107.996037        NaN
# 3121  56005     Campbell    Wyoming  44.248861 -105.547440        1.0
# 3122  56007       Carbon    Wyoming  41.693578 -106.932608        3.0
# 3123  56009     Converse    Wyoming  42.972723 -105.508185        2.0
# 3124  56011        Crook    Wyoming  44.588551 -104.569770        NaN
# 3125  56013      Fremont    Wyoming  43.041840 -108.629689        8.0
# 3126  56015       Goshen    Wyoming  42.087982 -104.353474        1.0
# 3127  56017  Hot Springs    Wyoming  43.719307 -108.442317        NaN
# 3128  56019      Johnson    Wyoming  44.040572 -106.584517        5.0
# 3129  56021      Laramie    Wyoming  41.307025 -104.688750        4.0
# 3130  56023      Lincoln    Wyoming  42.263764 -110.656400        4.0
# 3131  56025      Natrona    Wyoming  42.961801 -106.797885        4.0
# 3132  56027     Niobrara    Wyoming  43.056077 -104.475890        NaN
# 3133  56029         Park    Wyoming  44.521575 -109.585282        1.0
# 3134  56031       Platte    Wyoming  42.132991 -104.966331        NaN
# 3135  56033     Sheridan    Wyoming  44.790489 -106.886239        1.0
# 3136  56035     Sublette    Wyoming  42.765583 -109.913092        1.0
# 3137  56037   Sweetwater    Wyoming  41.659439 -108.882788        1.0
# 3138  56039        Teton    Wyoming  43.935225 -110.589080        2.0
# 3139  56041        Uinta    Wyoming  41.287818 -110.547578        3.0
# 3140  56043     Washakie    Wyoming  43.904516 -107.680187        1.0
# 3141  56045       Weston    Wyoming  43.839612 -104.567488        NaN
#
#       confirm_10  confirm_20  confirm_50  death_5  death_10  death_20  \
# 0           10.0         NaN         NaN      0.0       0.0       NaN
# 1            4.0        28.0         NaN      0.0       0.0       1.0
# 2            NaN         NaN         NaN      0.0       NaN       NaN
# 3            9.0         NaN         NaN      0.0       0.0       NaN
# 4            9.0         NaN         NaN      0.0       0.0       NaN
# 5            2.0         NaN         NaN      0.0       0.0       NaN
# 6            1.0         NaN         NaN      0.0       0.0       NaN
# 7            3.0        34.0         NaN      0.0       0.0       0.0
# 8           17.0       101.0         NaN      0.0       0.0       8.0
# 9            5.0         NaN         NaN      0.0       0.0       NaN
# 10          15.0         NaN         NaN      0.0       0.0       NaN
# 11           4.0         NaN         NaN      0.0       0.0       NaN
# 12           NaN         NaN         NaN      0.0       NaN       NaN
# 13           8.0         NaN         NaN      0.0       0.0       NaN
# 14           7.0         NaN         NaN      0.0       0.0       NaN
# 15           7.0         NaN         NaN      0.0       0.0       NaN
# 16           5.0         NaN         NaN      0.0       0.0       NaN
# 17           NaN         NaN         NaN      0.0       NaN       NaN
# 18           6.0         NaN         NaN      0.0       0.0       NaN
# 19           4.0         NaN         NaN      0.0       0.0       NaN
# 20           2.0         NaN         NaN      0.0       0.0       NaN
# 21           8.0        22.0         NaN      0.0       0.0       1.0
# 22           NaN         NaN         NaN      0.0       NaN       NaN
# 23           7.0         NaN         NaN      0.0       0.0       NaN
# 24          13.0         NaN         NaN      0.0       0.0       NaN
# 25           6.0        17.0         NaN      0.0       0.0       0.0
# 26           3.0         NaN         NaN      0.0       0.0       NaN
# 27          26.0         NaN         NaN      0.0       3.0       NaN
# 28           1.0         NaN         NaN      0.0       0.0       NaN
# 29           3.0         NaN         NaN      0.0       0.0       NaN
# ...          ...         ...         ...      ...       ...       ...
# 3112         NaN         NaN         NaN      NaN       NaN       NaN
# 3113        27.0        57.0         NaN      0.0       0.0       3.0
# 3114        20.0       101.0         NaN      0.0       0.0       1.0
# 3115         2.0         NaN         NaN      1.0       1.0       NaN
# 3116         NaN         NaN         NaN      NaN       NaN       NaN
# 3117         5.0        24.0         NaN      0.0       0.0       0.0
# 3118         1.0         2.0         NaN      0.0       0.0       0.0
# 3119         4.0         NaN         NaN      0.0       0.0       NaN
# 3120         NaN         NaN         NaN      NaN       NaN       NaN
# 3121         1.0         9.0         NaN      0.0       0.0       0.0
# 3122         3.0         4.0         NaN      0.0       0.0       0.0
# 3123         4.0         NaN         NaN      0.0       0.0       NaN
# 3124         NaN         NaN         NaN      NaN       NaN       NaN
# 3125        10.0        26.0         NaN      0.0       0.0       0.0
# 3126         2.0         NaN         NaN      0.0       0.0       NaN
# 3127         NaN         NaN         NaN      NaN       NaN       NaN
# 3128         8.0         NaN         NaN      0.0       0.0       NaN
# 3129        14.0        43.0         NaN      0.0       0.0       0.0
# 3130         NaN         NaN         NaN      0.0       NaN       NaN
# 3131        10.0        27.0         NaN      0.0       0.0       0.0
# 3132         NaN         NaN         NaN      NaN       NaN       NaN
# 3133         1.0         1.0         NaN      0.0       0.0       0.0
# 3134         NaN         NaN         NaN      NaN       NaN       NaN
# 3135         4.0        10.0         NaN      0.0       0.0       0.0
# 3136         1.0         NaN         NaN      0.0       0.0       NaN
# 3137         3.0         NaN         NaN      0.0       0.0       NaN
# 3138        13.0        41.0         NaN      0.0       0.0       0.0
# 3139         NaN         NaN         NaN      0.0       NaN       NaN
# 3140         4.0         NaN         NaN      0.0       0.0       NaN
# 3141         NaN         NaN         NaN      NaN       NaN       NaN
#
#       death_50  Population  Population Density  Median Household Income  \
# 0          NaN     55049.0           93.534505                  53099.0
# 1          NaN    199510.0          137.138546                  51365.0
# 2          NaN     26614.0           28.114060                  33956.0
# 3          NaN     22572.0           35.986169                  39776.0
# 4          NaN     57704.0           89.697955                  46212.0
# 5          NaN     10552.0           16.277951                  29335.0
# 6          NaN     20280.0           25.333449                  34315.0
# 7          NaN    115883.0          188.617140                  41954.0
# 8          NaN     34018.0           56.347976                  36027.0
# 9          NaN     25897.0           47.029486                  38925.0
# 10         NaN     43817.0           63.726498                  42594.0
# 11         NaN     13287.0           14.057424                  32622.0
# 12         NaN     24847.0           19.314926                  32735.0
# 13         NaN     13483.0           21.979895                  38815.0
# 14         NaN     14991.0           26.757507                  36316.0
# 15         NaN     50991.0           76.450752                  47872.0
# 16         NaN     54377.0           92.387121                  43786.0
# 17         NaN     12697.0           14.440131                  27609.0
# 18         NaN     10864.0           16.461552                  31910.0
# 19         NaN     37729.0           35.889346                  37313.0
# 20         NaN     13896.0           22.704544                  37557.0
# 21         NaN     81316.0          113.560424                  39297.0
# 22         NaN     49607.0           87.249907                  44093.0
# 23         NaN     41426.0           39.142244                  28136.0
# 24         NaN     70937.0           91.860910                  38248.0
# 25         NaN     80957.0          132.407566                  53398.0
# 26         NaN     37875.0           38.877616                  32334.0
# 27         NaN    103363.0          191.489768                  40478.0
# 28         NaN     16783.0           26.180383                  36205.0
# 29         NaN     31573.0           49.474811                  36138.0
# ...        ...         ...                 ...                      ...
# 3112       NaN     15685.0           19.919377                  44437.0
# 3113       NaN    133422.0          315.093380                  70325.0
# 3114       NaN    395377.0          733.230954                  78268.0
# 3115       NaN     51974.0           68.381104                  52441.0
# 3116       NaN     24238.0           38.748998                  46581.0
# 3117       NaN    169487.0          393.428317                  53501.0
# 3118       NaN     73621.0           92.123252                  49926.0
# 3119       NaN     37836.0            9.030895                  43043.0
# 3120       NaN     11931.0            3.787428                  50820.0
# 3121       NaN     48473.0            9.608366                  80822.0
# 3122       NaN     15696.0            1.895590                  56972.0
# 3123       NaN     14223.0            3.205668                  66737.0
# 3124       NaN      7284.0            2.609932                  60307.0
# 3125       NaN     40683.0            4.304526                  53559.0
# 3126       NaN     13546.0            6.010029                  44883.0
# 3127       NaN      4781.0            2.272468                  46087.0
# 3128       NaN      8572.0            2.036517                  54594.0
# 3129       NaN     96459.0           36.850715                  61201.0
# 3130       NaN     18543.0            4.768685                  64579.0
# 3131       NaN     80871.0           14.814087                  56983.0
# 3132       NaN      2498.0            0.909358                  40640.0
# 3133       NaN     29083.0            4.225945                  61185.0
# 3134       NaN      8740.0            4.115403                  41051.0
# 3135       NaN     29924.0           11.981242                  53914.0
# 3136       NaN     10032.0            2.008193                  76004.0
# 3137       NaN     44812.0            4.128808                  68233.0
# 3138       NaN     22623.0            5.774803                  75594.0
# 3139       NaN     20893.0            9.751068                  53323.0
# 3140       NaN      8351.0            3.522174                  46212.0
# 3141       NaN      7175.0            2.905332                  55640.0
#
#       Poverty Rate
# 0        12.165525
# 1        12.806877
# 2        23.427519
# 3        15.018607
# 4        16.361084
# 5        25.852919
# 6        25.276134
# 7        19.101162
# 8        20.004115
# 9        16.171757
# 10       20.035603
# 11       20.644239
# 12       24.240351
# 13       16.279760
# 14       19.271563
# 15       16.118531
# 16       16.385604
# 17       32.346224
# 18       14.819588
# 19       18.635532
# 20       17.875648
# 21       16.869989
# 22       19.950813
# 23       33.860378
# 24       19.555380
# 25       13.455291
# 26       23.482508
# 27       18.104157
# 28       17.058929
# 29       22.015646
# ...            ...
# 3112     12.598024
# 3113      5.610769
# 3114      5.100701
# 3115     10.249355
# 3116     10.916742
# 3117     11.548378
# 3118     10.479347
# 3119     23.971879
# 3120     11.608415
# 3121      8.041590
# 3122     13.589450
# 3123      8.282360
# 3124      6.054366
# 3125     13.728093
# 3126     14.993356
# 3127     10.960050
# 3128      5.821279
# 3129     10.172198
# 3130      8.714879
# 3131     10.304064
# 3132     11.849480
# 3133      7.867139
# 3134     15.331808
# 3135      7.946799
# 3136      7.725279
# 3137     10.863162
# 3138      7.293462
# 3139     16.570143
# 3140     14.345587
# 3141     13.965157
#
# [3142 rows x 17 columns]

# %%
file='hospitals.csv'
hospitals_df=pd.read_csv(file,encoding='ISO-8859-1')
hospitals_df
# Out:
#                                           hospital_name            city state  \
# 0                      GOODLAND REGIONAL MEDICAL CENTER        GOODLAND    KS
# 1                           MARIA PARHAM MEDICAL CENTER       HENDERSON    NC
# 2                    ALLEGHANY COUNTY MEMORIAL HOSPITAL          SPARTA    NC
# 3         ADVENTIST HEALTHCARE WHITE OAK MEDICAL CENTER   SILVER SPRING    MD
# 4                               ADVENTHEALTH LAKE WALES      LAKE WALES    FL
# 5                     NEWARK BETH ISRAEL MEDICAL CENTER          NEWARK    NJ
# 6                                   HOLY CROSS HOSPITAL         CHICAGO    IL
# 7                      FRANCES MAHON DEACONESS HOSPITAL         GLASGOW    MT
# 8                         AIKEN REGIONAL MEDICAL CENTER           AIKEN    SC
# 9                                      HIGHPOINT HEALTH    LAWRENCEBURG    IN
# 10                      PRISMA HEALTH BAPTIST PARKRIDGE        COLUMBIA    SC
# 11                                 ST JOSEPH'S HOSPITAL      SAINT PAUL    MN
# 12                  MEMORIAL HERMANN NORTHEAST HOSPITAL          HUMBLE    TX
# 13    PERMIAN REGIONAL MEDICAL CENTER ANDREWS COUNTY HO         ANDREWS    TX
# 14                                PHOENIXVILLE HOSPITAL    PHOENIXVILLE    PA
# 15                   HAZARD ARH REGIONAL MEDICAL CENTER          HAZARD    KY
# 16                           IROQUOIS MEMORIAL HOSPITAL         WATSEKA    IL
# 17                             ST JOSEPH MEDICAL CENTER         READING    PA
# 18               FERRELL HOSPITAL COMMUNITY FOUNDATIONS        ELDORADO    IL
# 19                                TAHOE FOREST HOSPITAL         TRUCKEE    CA
# 20                           COLUMBIA MEMORIAL HOSPITAL         ASTORIA    OR
# 21        ASCENSION COLUMBIA ST MARY'S HOSPITAL OZAUKEE          MEQUON    WI
# 22                   MISSISSIPPI BAPTIST MEDICAL CENTER         JACKSON    MS
# 23                               AUXILIO MUTUO HOSPITAL        HATO REY    PR
# 24                         LUTHERAN HOSPITAL OF INDIANA      FORT WAYNE    IN
# 25                           USC VERDUGO HILLS HOSPITAL        GLENDALE    CA
# 26                              CENTRAL DUPAGE HOSPITAL        WINFIELD    IL
# 27                     SCOTTSDALE OSBORN MEDICAL CENTER      SCOTTSDALE    AZ
# 28                                BACON COUNTY HOSPITAL            ALMA    GA
# 29                                 SINAI-GRACE HOSPITAL         DETROIT    MI
# ...                                                 ...             ...   ...
# 3548                            BERWICK HOSPITAL CENTER         BERWICK    PA
# 3549                           KETTERING MEDICAL CENTER       KETTERING    OH
# 3550                       METHODIST STONE OAK HOSPITAL     SAN ANTONIO    TX
# 3551                             HILL REGIONAL HOSPITAL       HILLSBORO    TX
# 3552                               SAN LEANDRO HOSPITAL     SAN LEANDRO    CA
# 3553                          NORTON COMMUNITY HOSPITAL          NORTON    VA
# 3554                    FRANCISCAN HEALTH MICHIGAN CITY   MICHIGAN CITY    IN
# 3555  CAREPOINT HEALTH-HOBOKEN UNIVERSITY MEDICAL CE...         HOBOKEN    NJ
# 3556               MAYO CLINIC HEALTH SYSTEM - FAIRMONT        FAIRMONT    MN
# 3557          JOHN MUIR MEDICAL CENTER - CONCORD CAMPUS         CONCORD    CA
# 3558                       HILLCREST HOSPITAL CLAREMORE       CLAREMORE    OK
# 3559              PIONEERS MEMORIAL HEALTHCARE DISTRICT         BRAWLEY    CA
# 3560                  NEWBERRY COUNTY MEMORIAL HOSPITAL        NEWBERRY    SC
# 3561                       WELLSTAR KENNESTONE HOSPITAL        MARIETTA    GA
# 3562                                   DAMERON HOSPITAL        STOCKTON    CA
# 3563                        PAGE MEMORIAL HOSPITAL, INC           LURAY    VA
# 3564                     BAXTER REGIONAL MEDICAL CENTER   MOUNTAIN HOME    AR
# 3565                       MONROE COUNTY MEDICAL CENTER   TOMPKINSVILLE    KY
# 3566                               DESERT VIEW HOSPITAL         PAHRUMP    NV
# 3567                          ST FRANCIS MEDICAL CENTER         TRENTON    NJ
# 3568                        ALLIANCE COMMUNITY HOSPITAL        ALLIANCE    OH
# 3569                     BAYFRONT HEALTH PORT CHARLOTTE  PORT CHARLOTTE    FL
# 3570                              SIERRA MEDICAL CENTER         EL PASO    TX
# 3571               UMD CHARLES REGIONAL  MEDICAL CENTER        LA PLATA    MD
# 3572                        FAIRBANKS MEMORIAL HOSPITAL       FAIRBANKS    AK
# 3573               VANDERBILT UNIVERSITY MEDICAL CENTER       NASHVILLE    TN
# 3574                              JENNERSVILLE HOSPITAL      WEST GROVE    PA
# 3575                                  MARINERS HOSPITAL       TAVERNIER    FL
# 3576                      JEWISH HOSPITAL - SHELBYVILLE     SHELBYVILLE    KY
# 3577                               GULF BREEZE HOSPITAL     GULF BREEZE    FL
#
#                county_name  hospital_overall_rating
# 0                  SHERMAN                        3
# 1                    VANCE                        2
# 2                ALLEGHANY                        2
# 3               MONTGOMERY                        3
# 4                     POLK                        1
# 5                    ESSEX                        3
# 6                     COOK                        2
# 7                   VALLEY                        4
# 8                    AIKEN                        2
# 9                 DEARBORN                        4
# 10               LEXINGTON                        5
# 11                  RAMSEY                        2
# 12                  HARRIS                        2
# 13                 ANDREWS                        3
# 14                 CHESTER                        2
# 15                   PERRY                        1
# 16                IROQUOIS                        2
# 17                   BERKS                        3
# 18                  SALINE                        3
# 19                  NEVADA                        4
# 20                 CLATSOP                        3
# 21                 OZAUKEE                        4
# 22                   HINDS                        4
# 23                SAN JUAN                        1
# 24                   ALLEN                        2
# 25             LOS ANGELES                        1
# 26                 DU PAGE                        4
# 27                MARICOPA                        3
# 28                   BACON                        3
# 29                   WAYNE                        1
# ...                    ...                      ...
# 3548              COLUMBIA                        4
# 3549            MONTGOMERY                        4
# 3550                 BEXAR                        4
# 3551                  HILL                        3
# 3552               ALAMEDA                        1
# 3553           NORTON CITY                        5
# 3554              LA PORTE                        4
# 3555                HUDSON                        1
# 3556                MARTIN                        4
# 3557          CONTRA COSTA                        5
# 3558                ROGERS                        4
# 3559              IMPERIAL                        1
# 3560              NEWBERRY                        4
# 3561                  COBB                        3
# 3562           SAN JOAQUIN                        3
# 3563                  PAGE                        5
# 3564                BAXTER                        2
# 3565                MONROE                        2
# 3566                   NYE                        3
# 3567                MERCER                        2
# 3568                 STARK                        4
# 3569             CHARLOTTE                        1
# 3570               EL PASO                        3
# 3571               CHARLES                        2
# 3572  FAIRBANKS NORTH STAR                        4
# 3573              DAVIDSON                        3
# 3574               CHESTER                        3
# 3575                MONROE                        5
# 3576                SHELBY                        4
# 3577            SANTA ROSA                        5
#
# [3578 rows x 5 columns]

# %%
#Merge county and hospital dataframes on county name
hospitals_df['county_name'] =hospitals_df['county_name'].str.capitalize()
h_df=hospitals_df.groupby(['county_name','state']).mean().reset_index()
State=[]
for row in h_df.itertuples(index=False):
    State.append(us.states.lookup(row.state).name)
h_df['State']=State
h_df=h_df[['State','county_name','hospital_overall_rating']]
h_df= h_df.rename(columns={'hospital_overall_rating': 'Average Hospital',
                                     'county_name':'County'})
merged_df = data_df.merge(h_df, how='inner', left_on=["State", "County"], right_on=["State","County"])

#Take a look at the dataframe
merged_df.head()
# Out:
#    FIPS   County    State   Latitude  Longitude  confirm_5  confirm_10  \
# 0  1001  Autauga  Alabama  32.539527 -86.644082        6.0        10.0
# 1  1003  Baldwin  Alabama  30.727750 -87.722071        1.0         4.0
# 2  1005  Barbour  Alabama  31.868263 -85.387129        3.0         NaN
# 3  1007     Bibb  Alabama  32.996421 -87.125115        4.0         9.0
# 4  1009   Blount  Alabama  33.982109 -86.567906        5.0         9.0
#
#    confirm_20  confirm_50  death_5  death_10  death_20  death_50  Population  \
# 0         NaN         NaN      0.0       0.0       NaN       NaN     55049.0
# 1        28.0         NaN      0.0       0.0       1.0       NaN    199510.0
# 2         NaN         NaN      0.0       NaN       NaN       NaN     26614.0
# 3         NaN         NaN      0.0       0.0       NaN       NaN     22572.0
# 4         NaN         NaN      0.0       0.0       NaN       NaN     57704.0
#
#    Population Density  Median Household Income  Poverty Rate  Average Hospital
# 0           93.534505                  53099.0     12.165525          5.000000
# 1          137.138546                  51365.0     12.806877          3.666667
# 2           28.114060                  33956.0     23.427519          3.000000
# 3           35.986169                  39776.0     15.018607          3.000000
# 4           89.697955                  46212.0     16.361084          3.000000

# %%
#Determine which measure of central tendency is most appropriate to describe the Population
plt.hist(merged_df['Population'])
plt.xlabel('Population')
plt.ylabel('Counts')
plt.show()
print(merged_df['Population'].mean())
print(merged_df['Population'].median())
print(merged_df['Population'].mode())
# Out:
# 143535.94882116158
# 46359.0
# 0      15578.0
# 1      17137.0
# 2      19384.0
# 3      19503.0
# 4      20324.0
# 5      25403.0
# 6      33765.0
# 7      37050.0
# 8      43198.0
# 9      53955.0
# 10    155817.0
# dtype: float64

# %%
#Summary statistics 
#Determine mean and mode for county level hospital quality
coun_hospital_quality_mean = round(merged_df['Average Hospital'].astype('float').mean(), 2)
coun_hospital_quality_median = round(merged_df['Average Hospital'].astype('float').median(), 2)
coun_hospital_quality_mode = round(merged_df['Average Hospital'].astype('float').mode(), 2)

#Mean and mode for hospital quality across all counties
print(f"County Level Hospital Rating Mean: {coun_hospital_quality_mean}")
print(f"County Level Hospital Rating Median: {coun_hospital_quality_median}")
print(f"County Level Hospital Rating mode {coun_hospital_quality_mode}")
# Out:
# County Level Hospital Rating Mean: 3.31
# County Level Hospital Rating Median: 3.07
# County Level Hospital Rating mode 0    4.0
# dtype: float64

# %%
#Summary statistics for hospital quality for each state 
state_stats_group=hospitals_df.groupby('state').agg({'hospital_overall_rating': ['mean', 'median', 'var', 'std', 'sem']})
#Average hospital quality for each state
state_stats_group['hospital_overall_rating']['mean'].plot.bar()
#Save file and output to png
plt.savefig('barplot.png')
#Create state level dataframe
pd.DataFrame (state_stats_group)
state_stats_group.head()
# Out:
#       hospital_overall_rating
#                          mean median       var       std       sem
# state
# AK                   3.400000    3.5  0.488889  0.699206  0.221108
# AL                   3.039474    3.0  0.945088  0.972156  0.111514
# AR                   2.806452    3.0  1.175040  1.083992  0.137667
# AZ                   3.072727    3.0  0.846465  0.920035  0.124058
# CA                   2.993031    3.0  1.321630  1.149621  0.067860

# %%
#Create function for bar charts of state level hospital quality
def bar_chart (x_axis,y_axis):

    plt.xlim(0, max(x_axis))
    plt.ylim(0, max(y_axis)+10)

    plt.bar(x_axis, y_axis, facecolor="red", alpha=0.75, align="center")

    # Set a Title and labels
    plt.title("Average Hospital Quality per Day 5 cases")
    plt.xlabel("Hospital Quality")
    plt.ylabel("Cases by Day 5")

    # Save plot as png 
    plt.tight_layout()
    plt.savefig("bar.png")
    plt.show()

# %%
bar_chart (state_data['Average Hospital'], state_data['confirm_5'])

# %%
bar_chart (state_data['Average Hospital'], state_data['confirm_10'])

# %%
bar_chart (state_data['Average Hospital'], state_data['confirm_20'])

# %%
bar_chart (state_data['Average Hospital'], state_data['death_5'])

# %%
bar_chart (state_data['Average Hospital'], state_data['death_10'])

# %%
bar_chart (state_data['Average Hospital'], state_data['death_20'])

# %%
#lowest and highest case rate at day 5 across all counties 
print(f"The minimum day 5 case rate across all counties is {merged_df['confirm_5'].min()}")
print(f"The maximum day 5 case rate across all counties is {merged_df['confirm_5'].max()}")
# Out:
# The minimum day 5 case rate across all counties is 0.0
# The maximum day 5 case rate across all counties is 83.0

# %%
#lowest and highest case rate at day 10 across all counties 
print(f"The minimum day 10 case rate across all counties is {merged_df['confirm_10'].min()}")
print(f"The maximum day 10 case rate across all counties is {merged_df['confirm_10'].max()}")
# Out:
# The minimum day 10 case rate across all counties is 0.0
# The maximum day 10 case rate across all counties is 326.0

# %%
#lowest and highest case rate at day 20 across all counties 
print(f"The minimum day 20 case rate across all counties is {merged_df['confirm_20'].min()}")
print(f"The maximum day 20 case rate across all counties is {merged_df['confirm_20'].max()}")
# Out:
# The minimum day 20 case rate across all counties is 0.0
# The maximum day 20 case rate across all counties is 3385.0

# %%
#lowest and highest case rate at day 50 across all counties 
print(f"The minimum day 50 case rate across all counties is {merged_df['confirm_50'].min()}")
print(f"The maximum day 50 case rate across all counties is {merged_df['confirm_50'].max()}")
# Out:
# The minimum day 50 case rate across all counties is 4.0
# The maximum day 50 case rate across all counties is 190.0

# %%
#lowest and highest death rate at day 5 across all counties 
print(f"The minimum day 5 death rate across all counties is {merged_df['death_5'].min()}")
print(f"The maximum day 5 death rate across all counties is {merged_df['death_5'].max()}")
# Out:
# The minimum day 5 death rate across all counties is 0.0
# The maximum day 5 death rate across all counties is 3.0

# %%
#lowest and highest death rate at day 10 across all counties 
print(f"The minimum day 10 death rate across all counties is {merged_df['death_10'].min()}")
print(f"The maximum day 10 death rate across all counties is {merged_df['death_10'].max()}")
# Out:
# The minimum day 10 death rate across all counties is 0.0
# The maximum day 10 death rate across all counties is 10.0

# %%
#lowest and highest case rate at day 20 across all counties 
print(f"The minimum day 20 death rate across all counties is {merged_df['death_20'].min()}")
print(f"The maximum day 20 death rate across all counties is {merged_df['death_20'].max()}")
# Out:
# The minimum day 20 death rate across all counties is 0.0
# The maximum day 20 death rate across all counties is 86.0

# %%
#lowest and highest death rate at day 50 across all counties 
print(f"The minimum day 50 death rate across all counties is {merged_df['death_50'].min()}")
print(f"The maximum day 50 death rate across all counties is {merged_df['death_50'].max()}")
# Out:
# The minimum day 50 death rate across all counties is 0.0
# The maximum day 50 death rate across all counties is 22.0

# %%
#lowest and highest population across all counties
print(f"The minimum population across all counties is {merged_df['Population'].min()}")
print(f"The maximum population across all counties is {merged_df['Population'].max()}")
# Out:
# The minimum population across all counties is 2348.0
# The maximum population across all counties is 5227575.0

# %%
#lowest and highest median income across all counties (in $1000s) observed
print(f"The minimum median income across all counties is {merged_df['Median Household Income'].min()}")
print(f"The maximum median income across all counties is {merged_df['Median Household Income'].max()}")
# Out:
# The minimum median income across all counties is 22174.0
# The maximum median income across all counties is 125672.0

# %%
# Determine if the hospital quality is normally distributed
plt.hist(merged_df['Average Hospital'].mean())
plt.xlabel('Hospital quality')
plt.ylabel('Deaths at Day 5')
plt.show()
print(st.normaltest(merged_df["Average Hospital"].sample(100)))
# Out:
# NormaltestResult(statistic=0.5074600230245496, pvalue=0.7759012581771512)

# %%
#Create function for bar charts of county level hospital quality
def bar_chart (x_axis,y_axis):

    plt.xlim(0, max(x_axis))
    plt.ylim(0, max(y_axis)+10)

    plt.bar(x_axis, y_axis, facecolor="red", alpha=0.75, align="center")
    #plt.xticks(tick_locations, gyms)

    # Set a Title and labels
    plt.title("Average Hospital Quality per Day 5 cases")
    plt.xlabel("Hospital Quality")
    plt.ylabel("Cases by Day 5")

    # Save our graph 
    plt.tight_layout()
    plt.savefig("bar.png")
    plt.show()

# %%
bar_chart (merged_df['Average Hospital'], merged_df['confirm_5'])

# %%
bar_chart (merged_df['Average Hospital'], merged_df['confirm_10'])

# %%
def scatterplot(x,y):
    # Convert to floats and store County level hospital rating and cases at Day 5
    temp_df=merged_df[[x,y]]
    temp_df=temp_df.dropna()
    x_values = temp_df[x].astype('float')
    y_values = temp_df[y].astype('float')
    # Run linear regression
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Plot scatter plot
    plt.scatter(x_values,y_values)
    # Plot regression line
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(3,np.max(y_values)*.9),fontsize=15,color="red")
    # Label plot
    plt.xlabel(x)
    plt.ylabel(y)
    # Print r square value
    print(f"R squared: {rvalue**2}")
    #save file and output to png
    plt.savefig('staterplot.png')
    # Show plot
    plt.show()

# %%
scatterplot('Average Hospital','confirm_5')
# Out:
# R squared: 0.007615232927483835

# %%
scatterplot('Average Hospital','death_5')
# Out:
# R squared: 0.0008793018554425203

# %%
scatterplot('Average Hospital','confirm_10')
# Out:
# R squared: 0.010415083585345085

# %%
scatterplot('Average Hospital','death_10')
# Out:
# R squared: 0.006249711391187893

# %%
scatterplot('Average Hospital','confirm_20')
# Out:
# R squared: 0.01615216468047862

# %%
scatterplot('Average Hospital','death_20')
# Out:
# R squared: 0.012056771353404293

# %%
scatterplot('Average Hospital','confirm_50')
# Out:
# R squared: 0.8255873908393623

# %%
scatterplot('Average Hospital','death_50')
# Out:
# R squared: 0.7720996161720673

# %%
#plot the latitude and longitude of hospital quality using Matplotlib, color the data points using the hospital quality of the block.
plt.scatter(merged_df['Longitude'], merged_df['Latitude'], c=merged_df['Average Hospital'])
clb = plt.colorbar()
plt.xlabel("Latitude")
plt.ylabel("Longitude")
clb.set_label("Hospital Quality")
plt.show()

# %%
#Create Heat maps 
#Configure gmaps with API key
gmaps.configure(api_key=gkey)

#Removing NAN values
#merged_data_complete_df = merged_df
# Store Latitude and Longitude into  locations 
#locations = census_data_complete_df[['Latitude', 'Longitude']]

# %%
# Convert Poverty Rate to float and store (removing NAN values)
census_data_complete = data_df.dropna()
locations = census_data_complete[['Latitude', 'Longitude']]
poverty_rate = census_data_complete["Poverty Rate"].astype(float)

census_data_florida=census_data_complete.loc[census_data_complete['State']=='Florida']
census_data_florida
# Out:
# Empty DataFrame
# Columns: [FIPS, County, State, Latitude, Longitude, confirm_5, confirm_10, confirm_20, confirm_50, death_5, death_10, death_20, death_50, Population, Population Density, Median Household Income, Poverty Rate]
# Index: []

# %%
# Create a poverty Heatmap layer
fig = gmaps.figure()

heat_map = gmaps.heatmap_layer(locations, weights=poverty_rate, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_map)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Convert day 5 case rate to list
day5_case_rate = census_data_complete["confirm_5"].tolist()

# %%
day5_case_rate
template="<dl><dd>confirm_5: {confirm_5}</dd></dl>"
infodata=[template.format(**row) for index,row in census_data_complete.iterrows()] 
infodata
# Out:
# ['<dl><dd>confirm_5: 1.0</dd></dl>',
#  '<dl><dd>confirm_5: 1.0</dd></dl>',
#  '<dl><dd>confirm_5: 1.0</dd></dl>',
#  '<dl><dd>confirm_5: 2.0</dd></dl>',
#  '<dl><dd>confirm_5: 2.0</dd></dl>',
#  '<dl><dd>confirm_5: 2.0</dd></dl>',
#  '<dl><dd>confirm_5: 1.0</dd></dl>',
#  '<dl><dd>confirm_5: 1.0</dd></dl>',
#  '<dl><dd>confirm_5: 1.0</dd></dl>']

# %%
# Create day 5 case rate symbol layer
template="<dl><dd>confirm_5: {confirm_5}</dd></dl>"
infodata=[template.format(**row) for index,row in census_data_complete.iterrows()] 
day5_case_layer = gmaps.symbol_layer(
    locations, #fill_color='rgba(0, 150, 0, 0.4)',
    #stroke_color='rgba(0, 0, 150, 0.4)', scale=2,
    info_box_content=infodata
    #info_box_content="<dl><dd>confirm_5: 10</dd></dl>"
)

fig = gmaps.figure()
fig.add_layer(day5_case_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create a combined map
fig = gmaps.figure()
fig.add_layer(heat_map)
fig.add_layer(day5_case_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create day 20 case rate symbol layer
template="<dl><dd>confirm_5: {confirm_20}</dd></dl>"
infodata=[template.format(**row) for index,row in census_data_complete.iterrows()] 
day20_case_layer = gmaps.symbol_layer(
    locations, #fill_color='rgba(0, 150, 0, 0.4)',
    #stroke_color='rgba(0, 0, 150, 0.4)', scale=2,
    info_box_content=infodata
    #info_box_content="<dl><dd>confirm_5: 10</dd></dl>"
)

fig = gmaps.figure()
fig.add_layer(day20_case_layer)
fig
print(locations)
# Out:
#        Latitude   Longitude
# 103   33.348359 -112.491815
# 204   34.308284 -118.228241
# 215   33.701475 -117.764600
# 220   36.603082 -121.069975
# 222   33.034846 -116.736533
# 228   37.231049 -121.697046
# 610   41.841448  -87.816588
# 1229  42.327951  -71.078504
# 2969  47.491379 -121.834613

# %%
# Create a combined map
fig = gmaps.figure()
fig.add_layer(heat_map)
fig.add_layer(day20_case_layer)
fig
print(day20_case_layer)
# Out:
# Markers(data_bounds=[(28.243000199014446, -144.0544709961997), (47.287638298763326, -76.3844864823759)], markers=[Symbol(display_info_box=True, fill_color=None, info_box_content='<dl><dd>confirm_5: 1.0</dd></dl>', location=(33.34835867, -112.49181540000001), scale=3, stroke_color=None), Symbol(display_info_box=True, fill_color=None, info_box_content='<dl><dd>confirm_5: 1.0</dd></dl>', location=(34.30828379, -118.22824109999999), scale=3, stroke_color=None), Symbol(display_info_box=True, fill_color=None, info_box_content='<dl><dd>confirm_5: 1.0</dd></dl>', location=(33.70147516, -117.76459979999998), scale=3, stroke_color=None), Symbol(display_info_box=True, fill_color=None, info_box_content='<dl><dd>confirm_5: 2.0</dd></dl>', location=(36.60308176, -121.069975), scale=3, stroke_color=None), Symbol(display_info_box=True, fill_color=None, info_box_content='<dl><dd>confirm_5: 2.0</dd></dl>', location=(33.03484597, -116.73653259999999), scale=3, stroke_color=None), Symbol(display_info_box=True, fill_color=None, info_box_content='<dl><dd>confirm_5: 2.0</dd></dl>', location=(37.23104908, -121.6970462), scale=3, stroke_color=None), Symbol(display_info_box=True, fill_color=None, info_box_content='<dl><dd>confirm_5: 2.0</dd></dl>', location=(41.84144849, -87.81658794), scale=3, stroke_color=None), Symbol(display_info_box=True, fill_color=None, info_box_content='<dl><dd>confirm_5: 1.0</dd></dl>', location=(42.327951399999996, -71.07850442), scale=3, stroke_color=None), Symbol(display_info_box=True, fill_color=None, info_box_content='<dl><dd>confirm_5: 1.0</dd></dl>', location=(47.49137892, -121.8346131), scale=3, stroke_color=None)])
